# %% [markdown]
# ## World Map Geovisualization using Folium and COVID data
#
# #### Coursera Guided Project
# #### Instructor: Vinita Silaparasetty
# #### Link: https://www.coursera.org/learn/python-world-map-geovisualization-dashboard-covid-data/ungradedLti/ihjMG/python-world-map-geovisualization-dashboard-using-covid-data

# %%
# !conda update pandas -y
# Out:
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working...
#
# Updating pandas is constricted by
#
# anaconda -> requires pandas==0.24.2=py37ha925a31_0
#
# If you are sure you want an update of your package either try `conda update --all` or install a specific version of the package you want using `conda install <pkg>=<version>`
#
# done
#
# ## Package Plan ##
#
#   environment location: C:\Users\isali\Anaconda3
#
#   added / updated specs:
#     - pandas
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2019.3.9           |           py37_0         155 KB
#     conda-4.8.5                |           py37_0         3.1 MB
#     deprecated-1.2.10          |             py_0          13 KB
#     descartes-1.1.0            |             py_3           9 KB
#     future-0.18.2              |           py37_1         746 KB
#     mapclassify-2.2.0          |             py_0          36 KB
#     munch-2.5.0                |             py_0          16 KB
#     ------------------------------------------------------------
#                                            Total:         4.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   deprecated         pkgs/main/noarch::deprecated-1.2.10-py_0
#
# The following packages will be REMOVED:
#
#   _anaconda_depends-2019.03-py37_0
#   python_abi-3.7-1_cp37m
#
# The following packages will be UPDATED:
#
#   conda              conda-forge::conda-4.8.3-py37hc8dfbb8~ --> pkgs/main::conda-4.8.5-py37_0
#   descartes          pkgs/main/win-64::descartes-1.1.0-py3~ --> pkgs/main/noarch::descartes-1.1.0-py_3
#   future                                      0.17.1-py37_0 --> 0.18.2-py37_1
#   mapclassify                                    2.0.1-py_0 --> 2.2.0-py_0
#   munch                pkgs/main/win-64::munch-2.3.2-py37_0 --> pkgs/main/noarch::munch-2.5.0-py_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi                                       conda-forge --> pkgs/main
#
#
#
# Downloading and Extracting Packages
#
# deprecated-1.2.10    | 13 KB     |            |   0%
# deprecated-1.2.10    | 13 KB     | ########## | 100%
#
# conda-4.8.5          | 3.1 MB    |            |   0%
# conda-4.8.5          | 3.1 MB    | ########## | 100%
#
# future-0.18.2        | 746 KB    |            |   0%
# future-0.18.2        | 746 KB    | ########## | 100%
#
# descartes-1.1.0      | 9 KB      |            |   0%
# descartes-1.1.0      | 9 KB      | ########## | 100%
#
# certifi-2019.3.9     | 155 KB    |            |   0%
# certifi-2019.3.9     | 155 KB    | ########## | 100%
#
# munch-2.5.0          | 16 KB     |            |   0%
# munch-2.5.0          | 16 KB     | ########## | 100%
#
# mapclassify-2.2.0    | 36 KB     |            |   0%
# mapclassify-2.2.0    | 36 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %%
import pandas as pd
pd.__version__
# Out:
# '0.24.2'

# %%
# Import Libraries

import json
import folium
import requests
import mimetypes
import http.client
import pandas as pd
from folium.plugins import HeatMap
from pandas.io.json import json_normalize

# %% [markdown]
# ### Access Data via API

# %%
conn = http.client.HTTPSConnection("api.covid19api.com")
payload=''
headers={}
conn.request("GET", "/summary", payload, headers)
res=conn.getresponse()
data=res.read().decode('UTF-8')

# %% [markdown]
# ### Convert Data to JSON

# %%
covid1=json.loads(data)

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Normalize the Data

# %%
pd.json_normalize(covid1['Countries'], sep=',')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input
# 185                   Western Sahara          EH  2020-10-18T21:23:07Z
# 186                            Yemen          YE  2020-10-18T21:23:07Z
# 187                           Zambia          ZM  2020-10-18T21:23:07Z
# 188                         Zimbabwe          ZW  2020-10-18T21:23:07Z
#
#      NewConfirmed  NewDeaths  NewRecovered Premium                    Slug  \
# 0              68          3            45      {}             afghanistan
# 1             273          5            44      {}                 albania
# 2             205          5           115      {}                 algeria
# 3               0          0             0      {}                 andorra
# 4             240          7            10      {}                  angola
# 5               7          0             1      {}     antigua-and-barbuda
# 6           13510        384         12673      {}               argentina
# 7            1540         11           384      {}                 armenia
# 8              12          0             1      {}               australia
# 9            1747          7          1153      {}                 austria
# 10            528          2           103      {}              azerbaijan
# 11            111          2            75      {}                 bahamas
# 12            246          1           420      {}                 bahrain
# 13           1209         23          1560      {}              bangladesh
# 14              0          0             0      {}                barbados
# 15            671          4           439      {}                 belarus
# 16          10964         33           207      {}                 belgium
# 17             47          0            22      {}                  belize
# 18              0          0             0      {}                   benin
# 19              9          0             1      {}                  bhutan
# 20            148         24           306      {}                 bolivia
# 21            716          1           170      {}  bosnia-and-herzegovina
# 22              0          0             0      {}                botswana
# 23          24062        461             0      {}                  brazil
# 24              0          0             0      {}                  brunei
# 25            603         10            37      {}                bulgaria
# 26              0          0             0      {}            burkina-faso
# 27              5          0             0      {}                 burundi
# 28              0          0             0      {}                cambodia
# 29              0          0             0      {}                cameroon
# ..            ...        ...           ...     ...                     ...
# 159             0          0             0      {}                   spain
# 160           121          0            10      {}               sri-lanka
# 161             0          0             0      {}                   sudan
# 162            10          0            15      {}                suriname
# 163            19          0             0      {}               swaziland
# 164             0          0             0      {}                  sweden
# 165             0          0           100      {}             switzerland
# 166            46          4            38      {}                   syria
# 167             0          0             0      {}                  taiwan
# 168            41          0            64      {}              tajikistan
# 169             0          0             0      {}                tanzania
# 170             7          0             3      {}                thailand
# 171             0          0             0      {}             timor-leste
# 172            22          0            17      {}                    togo
# 173            40          0            39      {}     trinidad-and-tobago
# 174          5752        114             0      {}                 tunisia
# 175          1723         71          1401      {}                  turkey
# 176           121          0             0      {}                  uganda
# 177          6629        118          2312      {}                 ukraine
# 178          1538          4          1411      {}    united-arab-emirates
# 179         16186        150             7      {}          united-kingdom
# 180         57519        711         23034      {}           united-states
# 181            51          0            10      {}                 uruguay
# 182           221          2           132      {}              uzbekistan
# 183           531          6           553      {}               venezuela
# 184             2          0             0      {}                 vietnam
# 185             0          0             0      {}          western-sahara
# 186             0          0             1      {}                   yemen
# 187           130          0            28      {}                  zambia
# 188            11          0             0      {}                zimbabwe
#
#      TotalConfirmed  TotalDeaths  TotalRecovered
# 0             40141         1488           33561
# 1             16774          448           10001
# 2             54203         1846           37971
# 3              3377           59            2057
# 4              7462          241            3022
# 5               119            3             101
# 6            979119        26107          791174
# 7             63000         1067           47925
# 8             27390          904           25098
# 9             63134          889           48771
# 10            44317          623           39903
# 11             5628          116            3276
# 12            77571          293           73841
# 13           387295         5646          302298
# 14              219            7             195
# 15            87063          925           79429
# 16           213115        10392           21074
# 17             2775           43            1648
# 18             2496           41            2330
# 19              325            0             299
# 20           139710         8463          104202
# 21            33561          981           24773
# 22             5242           20             905
# 23          5224362       153675         4526393
# 24              147            3             143
# 25            29108          968           16912
# 26             2343           65            1718
# 27              536            1             497
# 28              283            0             280
# 29            21441          423           20117
# ..              ...          ...             ...
# 159          936560        33775          150376
# 160            5475           13            3395
# 161           13691          836            6764
# 162            5123          109            4936
# 163            5765          115            5392
# 164          103200         5918               0
# 165           74422         2122           50600
# 166            5033          245            1494
# 167             535            7             491
# 168           10455           80            9457
# 169             509           21             183
# 170            3686           59            3481
# 171              29            0              28
# 172            2049           51            1517
# 173            5281           95            3584
# 174           40542          626            5032
# 175          345678         9224          302499
# 176           10455           96            6901
# 177          301856         5669          129033
# 178          114387          459          106354
# 179          708298        43669            2572
# 180         8106384       219286         3220573
# 181            2501           51            2052
# 182           62809          522           59756
# 183           86289          731           78847
# 184            1126           35            1031
# 185              10            1               8
# 186            2055          596            1336
# 187           15789          346           14927
# 188            8110          231            7673
#
# [189 rows x 11 columns]

# %% [markdown]
# ### Drop Unnecessary Columns

# %%
covid2= df.drop(columns=['CountryCode', 'Slug', 'Date', 'Premium'], axis=1)
covid2

# %% [markdown]
# ### Generate Base Map

# %%
m=folium.Map(tiles="Stamen Terrain", min_zoom=1.5)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Obtain Geodata
#
# geodata url: https://raw.githubusercontent.com/python-visualization/folium/master/examples/data
#
# geo data file: world-countries.json

# %%
url='https://raw.githubusercontent.com/python-visualization/folium/master/examples/data'
country_shapes=f'{url}/world-countries.json'

# %% [markdown]
# ### Generate Choropleth Map Layer

# %%
folium.Choropleth(
    geo_data=country_shapes,
    min_zoom=2,
    name='COVID-19',
    data=covid2,
    columns=['Country', 'TotalConfirmed'],
    key_on='feature.properties.name',
    fill_color='OrRd',
    nan_fill_color='black',
    legend_name='Total Confirmed COVID Cases',
).add_to(m)
m
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-be7de5e147c6> in <module>
#       3     min_zoom=2,
#       4     name='COVID-19',
# ----> 5     data=covid2,
#       6     columns=['Country', 'TotalConfirmed'],
#       7     key_on='feature.properties.name',
#
# NameError: name 'covid2' is not defined

# %% [markdown]
# ### Generate Circular Markers

# %%
covid2.update(covid2['TotalConfirmed'].map('Total Confirmed:{}'.format))
covid2.update(covid2['TotalRecovered'].map('Total Recovered:{}'.format))

# %% [markdown]
# coordinates of countries: https://raw.githubusercontent.com/VinitaSilaparasetty/covid-map/master/country-coordinates-world.csv

# %%
coordinates= pd.read_csv('https://raw.githubusercontent.com/VinitaSilaparasetty/covid-map/master/country-coordinates-world.csv')
coordinates

# %%
covid_final=pd.merge(covid2, coordinates, on='Country')

# %%
def plotDot(point):
    folium.CircleMarker(location=[point.latitude, point.longitude],
                       radius=5,
                       weight=2,
                       popup=[point.Country, point.TotalConfirmed, point.TotalRecovered],
                       fill_color='#000000').add_to(m)

# %%
covid_final.apply(plotDot, axis=1)
m.fit_bounds(m.get_bounds())
m

# %% [markdown]
# ### Generate Base Map

# %%
m1= folium.Map(tiles='StamenToner', min_zoom=2)
m1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Generate Heat Map Layer

# %%
deaths=covid_final['TotalDeaths'].astype(float)

# %%
lat=covid_final['latitude'].astype(float)

# %%
lon=covid_final['longitude'].astype(float)

# %%
m1.add_child(HeatMap(zip(lat, lon, deaths), radius=0))

# %% [markdown]
# ### Generate Circular Markers

# %%
def plotDot(point):
    folium.CircleMarker(location=[point.latitude, point.longitude],
                       radius=5,
                       weight=2,
                       popup=[point.Country, point.TotalDeaths],
                       fill_color='#000000').add_to(m1)
covid_final.apply(plotDot, axis=1)
m1.fit_bounds(m1.get_bounds())
m1
